# %%
import torch
print(torch.__version__)
# Out:
# 2.11.0+cpu

# %%
if torch.cude.is_avaible():
  print("GPu is available")
else:
  print("Gpu is not avaible")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2805/3716771001.py in <cell line: 0>()
# ----> 1 if torch.cude.is_avaible():
#       2   print("GPu is available")
#       3 else:
#       4   print("Gpu is not avaible")
#
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py in __getattr__(name)
#    2879             return importlib.import_module(f".{name}", __name__)
#    2880
# -> 2881         raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#    2882
#    2883
#
# AttributeError: module 'torch' has no attribute 'cude'

# %%
import torch

if torch.cuda.is_available():
    print("GPU is available")
else:
    print("GPU is not available")
# Out:
# GPU is not available

# %%
torch.empty(2,33)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3250/2419610809.py in <cell line: 0>()
# ----> 1 torch.empty(2,33)
#
# NameError: name 'torch' is not defined

# %%
import torch

if torch.cuda.is_available():
  print("GPU is availble")


else:
  print("GPU is not available")
# Out:
# GPU is availble

# %%
import torch
if torch.cuda.is_available():
  print("GPU is available")

else:
  print("GPU is not available")
# Out:
# GPU is available

# %%
# Creating a tensor

# %% [markdown]
# #creating a tensor

# %%
torch.empty(2,3)
# Out:
# tensor([[-7.8635e+07,  4.3436e-41,  9.9705e-33],
#         [ 4.3439e-41,  1.6339e-38,  0.0000e+00]])

# %%
import torch
a = torch.empty(22,33)

# %%
type(a)
# Out:
# torch.Tensor

# %%
torch.zeros(2,3)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
torch.ones(2,3)
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
torch.zeros(2,3)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
a = torch.rand(2,4)

# %%
type(a)
# Out:
# torch.Tensor

# %%
torch.manual_seed(100)
torch.rand(2,3)
# Out:
# tensor([[0.1117, 0.8158, 0.2626],
#         [0.4839, 0.6765, 0.7539]])
